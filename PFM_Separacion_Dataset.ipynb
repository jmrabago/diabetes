# %%
# Librerías a importar
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Leyendo el dataset
df = pd.read_csv('../Trabajo Fin de Master/diabetes.csv')

# %%
df.shape
# Out:
# (295971, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295971 entries, 0 to 295970
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   salud_gral             295971 non-null  float64
#  1   sexo                   295971 non-null  float64
#  2   raza_etnicidad         295971 non-null  float64
#  3   edad                   295971 non-null  float64
#  4   ingreso_anual          295971 non-null  float64
#  5   empleado               295971 non-null  float64
#  6   nvl_educacion          295971 non-null  float64
#  7   presion_alta           295971 non-null  float64
#  8   colesterol_alto        295971 non-null  float64
#  9   dif_caminar            295971 non-null  float64
#  10  ciego_o_dif_ver        295971 non-null  float64
#  11  fumador                295971 non-null  float64
#  12  alcoholismo            295971 non-null  float64
#  13  indice_masa_corporal   295971 non-null  float64
# ...

# %%
# Separamos el dataset en 2, uno que equivale el 90% que es para entrenar y el otro para predecir
df_train, df_predict = train_test_split(df, test_size=0.1, random_state=42)

# %%
print(df_train.shape)
print(df_predict.shape)
# Out:
# (266373, 22)
# (29598, 22)

# %%
df_train.to_csv('diabetes_entrenar.csv')
# Out:
# (266373, 22)

# %%
df_predict.shape
# Out:
# (29598, 22)
