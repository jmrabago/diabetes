# %%
# Importación de librerías
import pandas as pd

# %%
# Variable con la dirección del archivo en formato XPT
xpt_file = '../Trabajo Fin de Master/LLCP2023.XPT '
# Lectura del dataset en formato XPT 
df = pd.read_sas(xpt_file, format='xport')

# %%
# Variable con el nombre que se le asigna al archivo
csv_file = '2023 BRFSS Survey Data.csv'
# Conversión del dataset de formato XPT a formato CSV
df.to_csv(csv_file, index=False)

# %%
# Lectura del dataset en formato CSV 
df = pd.read_csv('../Trabajo Fin de Master/2023 BRFSS Survey Data.csv')

# %%
df.shape
# Out:
# (433323, 350)

# %%
# Out:
# <bound method NDFrame.head of         _STATE  FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE  \
# 0          1.0     1.0  b'03012023'  b'03'  b'01'  b'2023'    1100.0
# 1          1.0     1.0  b'01062023'  b'01'  b'06'  b'2023'    1100.0
# 2          1.0     1.0  b'03082023'  b'03'  b'08'  b'2023'    1100.0
# 3          1.0     1.0  b'03062023'  b'03'  b'06'  b'2023'    1100.0
# 4          1.0     1.0  b'01062023'  b'01'  b'06'  b'2023'    1100.0
# ...        ...     ...          ...    ...    ...      ...       ...
# 433318    78.0    12.0  b'12112023'  b'12'  b'11'  b'2023'    1100.0
# 433319    78.0    12.0  b'01032024'  b'01'  b'03'  b'2024'    1100.0
# 433320    78.0    12.0  b'12132023'  b'12'  b'13'  b'2023'    1100.0
# 433321    78.0    12.0  b'12082023'  b'12'  b'08'  b'2023'    1100.0
# 433322    78.0    12.0  b'12112023'  b'12'  b'11'  b'2023'    1100.0
#
#                 SEQNO          _PSU  CTELENM1  ...      DROCDY4_  _RFBING6  \
# ...
